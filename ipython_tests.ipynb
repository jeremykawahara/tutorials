# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
img = plt.imread('//cs/ghassan/students/jkawahar/Project/SkinClassify/dermofit/papers/isbi2016/figs/dermofit-imgs-row.png')
plt.figure(figsize=(10,10))
plt.imshow(img)

# %% [markdown]
# $\LaTeX$ example   $f(x)=\frac{x^2}{2}$

# %%
32+32
# Out:
# 64
